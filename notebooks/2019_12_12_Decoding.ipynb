# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
epoch_key = ('Roqui', 5, 2)

# %%
from src.load_data import load_data
from src.parameters import ANIMALS

data = load_data(epoch_key)

# %%
data['position_info']
# Out:
#                      nose_x     nose_y   nose_vel  tailBase_x  tailBase_y  \
# time
# 00:25:01.474544  106.024191  90.565393 -19.466150   85.426632   92.204578
# 00:25:01.476544  101.157653  85.017710 -14.589996   85.426825   92.205845
# 00:25:01.478544   96.291116  79.470027  -9.713841   85.427018   92.207111
# 00:25:01.480544   91.424578  73.922343  -4.837687   85.427211   92.208377
# 00:25:01.482544   86.558041  68.374660   0.038467   85.427404   92.209643
# ...                     ...        ...        ...         ...         ...
# 00:42:29.092544   85.988675   5.613837  -0.006989   85.959252    6.588972
# 00:42:29.094544   85.986928   5.616639  -0.006356   85.959609    6.585407
# 00:42:29.096544   85.985181   5.619440  -0.005723   85.959965    6.581842
# 00:42:29.098544   85.983433   5.622242  -0.005090   85.960322    6.578277
# 00:42:29.100544   85.981686   5.625044  -0.004457   85.960679    6.574712
#
#                  tailBase_vel  tailMid_x  tailMid_y  tailMid_vel  tailTip_x  \
# time
# 00:25:01.474544      0.000772  79.207901  95.303589     0.000827  73.884647
# 00:25:01.476544      0.000690  79.208108  95.303932     0.000676  73.884773
# 00:25:01.478544      0.000608  79.208314  95.304276     0.000526  73.884899
# 00:25:01.480544      0.000526  79.208521  95.304619     0.000376  73.885025
# 00:25:01.482544      0.000444  79.208728  95.304962     0.000226  73.885150
# ...                       ...        ...        ...          ...        ...
# 00:42:29.092544      0.001427  76.707176   7.303529    -0.009478  69.100159
# 00:42:29.094544      0.001016  76.704807   7.303631    -0.007215  69.099832
# 00:42:29.096544      0.000604  76.702438   7.303733    -0.004952  69.099506
# 00:42:29.098544      0.000193  76.700068   7.303835    -0.002690  69.099180
# 00:42:29.100544     -0.000219  76.697699   7.303937    -0.000427  69.098854
#
#                  ...  hindpawL_x  hindpawL_y  hindpawL_vel  hindpawR_x  \
# time             ...
# 00:25:01.474544  ...   91.239169   90.140545     -0.002439   89.223088
# 00:25:01.476544  ...   91.238559   90.140080     -0.000939   89.223168
# 00:25:01.478544  ...   91.237950   90.139614      0.000560   89.223248
# 00:25:01.480544  ...   91.237340   90.139149      0.002060   89.223329
# 00:25:01.482544  ...   91.236730   90.138683      0.003559   89.223409
# ...              ...         ...         ...           ...         ...
# 00:42:29.092544  ...   92.182255    3.744183      0.004736   94.627338
# 00:42:29.094544  ...   92.183439    3.744495     -0.014940   94.627071
# 00:42:29.096544  ...   92.184623    3.744807     -0.034617   94.626804
# 00:42:29.098544  ...   92.185807    3.745119     -0.054293   94.626538
# 00:42:29.100544  ...   92.186991    3.745431     -0.073970   94.626271
#
#                  hindpawR_y  hindpawR_vel  linear_distance  track_segment_id  \
# time
# 00:25:01.474544   94.396685      0.000321       218.611390               3.0
# 00:25:01.476544   94.397670     -0.016983       218.611583               3.0
# 00:25:01.478544   94.398655     -0.034287       218.611776               3.0
# 00:25:01.480544   94.399641     -0.051591       218.611969               3.0
# 00:25:01.482544   94.400626     -0.068895       218.612162               3.0
# ...                     ...           ...              ...               ...
# 00:42:29.092544    7.968509     -0.001067       220.505315               4.0
# 00:42:29.094544    7.968404      0.001127       220.505713               4.0
# 00:42:29.096544    7.968299      0.003322       220.506110               4.0
# 00:42:29.098544    7.968193      0.005516       220.506508               4.0
# 00:42:29.100544    7.968088      0.007710       220.506905               4.0
#
#                  linear_position   arm_name
# time
# 00:25:01.474544       356.682999   Left Arm
# 00:25:01.476544       356.683192   Left Arm
# 00:25:01.478544       356.683385   Left Arm
# 00:25:01.480544       356.683578   Left Arm
# 00:25:01.482544       356.683771   Left Arm
# ...                          ...        ...
# 00:42:29.092544       641.351708  Right Arm
# 00:42:29.094544       641.352106  Right Arm
# 00:42:29.096544       641.352503  Right Arm
# 00:42:29.098544       641.352901  Right Arm
# 00:42:29.100544       641.353298  Right Arm
#
# [523814 rows x 28 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 5))

for edge_label, df in data['position_info'].groupby('arm_name'):
    ax.scatter(df.index / np.timedelta64(1, 's'), df.linear_position, s=1)
    
ax.set_ylabel('Position [cm]')
ax.set_xlabel('Time [s]');

# %%
data['multiunits']
# Out:
# <xarray.DataArray (time: 523814, features: 4, tetrodes: 14)>
# array([[[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#         [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#         [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#         [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#        [[ nan,  69.,  44., ...,  nan,  nan,  nan],
#         [ nan, -26.,   1., ...,  nan,  nan,  nan],
#         [ nan, -22.,  12., ...,  nan,  nan,  nan],
#         [ nan,  40.,  86., ...,  nan,  nan,  nan]],
#
#        [[ nan,  nan,  nan, ...,  nan,  nan,  36.],
#         [ nan,  nan,  nan, ...,  nan,  nan,  62.],
#         [ nan,  nan,  nan, ...,  nan,  nan,  50.],
#         [ nan,  nan,  nan, ...,  nan,  nan,  31.]],
#
#        ...,
#
#        [[ 98.,  nan,  nan, ...,  nan,  nan,  nan],
#         [ 50.,  nan,  nan, ...,  nan,  nan,  nan],
#         [141.,  nan,  nan, ...,  nan,  nan,  nan],
#         [ 82.,  nan,  nan, ...,  nan,  nan,  nan]],
#
#        [[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#         [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#         [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#         [ nan,  nan,  nan, ...,  nan,  nan,  nan]],
#
#        [[ 76.,  nan,  nan, ...,  nan,  nan,  nan],
#         [ 41.,  nan,  nan, ...,  nan,  nan,  nan],
#         [120.,  nan,  nan, ...,  nan,  nan,  nan],
#         [ 77.,  nan,  nan, ...,  nan,  nan,  nan]]])
# Coordinates:
#   * time      (time) timedelta64[ns] 00:25:01.474544 ... 00:42:29.100544
#   * features  (features) <U13 'channel_1_max' ... 'channel_4_max'
# Dimensions without coordinates: tetrodes

# %%
from dask.distributed import Client

client = Client(n_workers=1,
                threads_per_worker=1,
                processes=True,
                memory_limit='25GB')

# %%
from replay_trajectory_classification import ClusterlessDecoder

track_labels = data['position_info'].arm_name

decoder = ClusterlessDecoder(
    transition_type='w_track_1D_random_walk',
    replay_speed=40,
    place_bin_size=5,
    track_labels=track_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-109f07e425f7> in <module>
#       1 from replay_trajectory_classification import ClusterlessDecoder
#       2
# ----> 3 track_labels = data['position_info'].arm_name
#       4
#       5 decoder = ClusterlessDecoder(
#
# NameError: name 'data' is not defined
