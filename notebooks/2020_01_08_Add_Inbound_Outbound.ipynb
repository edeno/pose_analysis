# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
epoch_key = ('Roqui', 5, 2)

# %%
from src.load_data import get_interpolated_position_info

position_info = get_interpolated_position_info(epoch_key)
# Out:
# /home/edeno/miniconda3/envs/pose_analysis/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:899: RuntimeWarning: invalid value encountered in greater_equal
#   return (a <= x) & (x <= b)
# /home/edeno/miniconda3/envs/pose_analysis/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:899: RuntimeWarning: invalid value encountered in less_equal
#   return (a <= x) & (x <= b)
# /home/edeno/miniconda3/envs/pose_analysis/lib/python3.6/site-packages/loren_frank_data_processing/track_segment_classification.py:275: RuntimeWarning: divide by zero encountered in log
#   state_transition = np.log(state_transition.copy()[~is_nan])
# Failed to load file: /home/edeno/Documents/Github/pose_analysis/src/../Raw-Data/Roqui/RoquiDIO05.mat
# No DIO file found, using distance from well to segment trials
# Failed to load file: /home/edeno/Documents/Github/pose_analysis/src/../Raw-Data/Roqui/RoquiDIO05.mat
# No DIO file found, inferring correct inbound/outbound from task rules

# %%
plt.figure(figsize=(20, 5))

for name, df in position_info.groupby('arm_name'):
    plt.scatter(df.index / np.timedelta64(1, 's'), df.linear_position)

# %%
plt.figure(figsize=(30, 3))

plt.scatter(position_info.index / np.timedelta64(1, 's'), position_info.linear_position, color='lightgrey', s=10)

for name, df in position_info.groupby('task'):
    plt.scatter(df.index / np.timedelta64(1, 's'), df.linear_position, s=10)

# %%
from src.load_data import load_data

data = load_data(epoch_key)
# Out:
# /home/edeno/miniconda3/envs/pose_analysis/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:899: RuntimeWarning: invalid value encountered in greater_equal
#   return (a <= x) & (x <= b)
# /home/edeno/miniconda3/envs/pose_analysis/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:899: RuntimeWarning: invalid value encountered in less_equal
#   return (a <= x) & (x <= b)
# /home/edeno/miniconda3/envs/pose_analysis/lib/python3.6/site-packages/loren_frank_data_processing/track_segment_classification.py:275: RuntimeWarning: divide by zero encountered in log
#   state_transition = np.log(state_transition.copy()[~is_nan])
# Failed to load file: /home/edeno/Documents/Github/pose_analysis/src/../Raw-Data/Roqui/RoquiDIO05.mat
# No DIO file found, using distance from well to segment trials
# Failed to load file: /home/edeno/Documents/Github/pose_analysis/src/../Raw-Data/Roqui/RoquiDIO05.mat
# No DIO file found, inferring correct inbound/outbound from task rules

# %%
plt.figure(figsize=(30, 3))

plt.scatter(pos_df.index / np.timedelta64(1, 's'), pos_df.linear_position, color='lightgrey', s=10)

for task, df in pos_df.groupby('task'):
    plt.scatter(df.index / np.timedelta64(1, 's'), df.linear_position, label=task, s=10)

plt.legend()
